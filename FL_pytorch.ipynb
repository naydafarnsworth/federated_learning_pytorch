# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from tqdm import tqdm


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        self.fc1 = nn.Linear(2048, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.conv3(x)
        x = F.relu(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        output = F.log_softmax(x, dim=1)
        return output


def client_update(client_model, optimizer, train_loader, epoch=5):
    model.train()
    for e in range(epoch):
        for batch_idx, (data, target) in enumerate(train_loader):
         #    data, target = data.cuda(), target.cuda()
            optimizer.zero_grad()
            output = client_model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()
    return loss.item()

def server_aggregate(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
        global_dict[k] = torch.stack([client_models[i].state_dict()[k] for i in range(len(client_models))], 0).mean(0)
    global_model.load_state_dict(global_dict)
    for model in client_models:
        model.load_state_dict(global_model.state_dict())

def test(global_model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            # data, target = data.cuda(), target.cuda()
            output = global_model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    acc = correct / len(test_loader.dataset)

    return test_loss, acc

# %%
# IID case: all the clients have images of all the classes

# Hyperparameters

num_clients = 100
num_selected = 10
num_rounds = 5
epochs = 5
batch_size = 32

# Creating decentralized datasets

traindata = datasets.MNIST('./data', train=True, download=True,
                       transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,))])
                       )
traindata_split = torch.utils.data.random_split(traindata, [int(traindata.data.shape[0] / num_clients) for _ in range(num_clients)])
train_loader = [torch.utils.data.DataLoader(x, batch_size=batch_size, shuffle=True) for x in traindata_split]

test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('./data', train=False, transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,))])
        ), batch_size=batch_size, shuffle=True)

# Instantiate models and optimizers

global_model = Net() # .cuda()
client_models = [Net() for _ in range(num_selected)]
for model in client_models:
    model.load_state_dict(global_model.state_dict())

opt = [optim.SGD(model.parameters(), lr=0.1) for model in client_models]

# Runnining FL

for r in range(num_rounds):
    # select random clients
    client_idx = np.random.permutation(num_clients)[:num_selected]

    # client update
    loss = 0
    for i in range(num_selected):
        loss += client_update(client_models[i], opt[i], train_loader[client_idx[i]], epoch=epochs)
    
    # serer aggregate
    server_aggregate(global_model, client_models)
    test_loss, acc = test(global_model, test_loader)
    
    print('%d-th round' % r)
    print('average train loss %0.3g | test loss %0.3g | test acc: %0.3f' % (loss / num_selected, test_loss, acc))
# Out:
# 0-th round
# average train loss 0.65 | test loss 0.505 | test acc: 0.860
# 1-th round
# average train loss 0.186 | test loss 0.26 | test acc: 0.923
# 2-th round
# average train loss 0.128 | test loss 0.203 | test acc: 0.942
# 3-th round
# average train loss 0.0278 | test loss 0.163 | test acc: 0.954
# 4-th round
# average train loss 0.0121 | test loss 0.149 | test acc: 0.959

# %%
# NON-IID case: every client has images of two categories chosen from [0, 1], [2, 3], [4, 5], [6, 7], or [8, 9].

# Hyperparameters

num_clients = 100
num_selected = 5
num_rounds = 50
epochs = 5
batch_size = 32

# Creating decentralized datasets

traindata = datasets.MNIST('./data', train=True, download=True,
                       transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,))])
                       )
target_labels = torch.stack([traindata.targets == i for i in range(10)])
target_labels_split = []
for i in range(5):
    target_labels_split += torch.split(torch.where(target_labels[(2 * i):(2 * (i + 1))].sum(0))[0], int(60000 / num_clients))
traindata_split = [torch.utils.data.Subset(traindata, tl) for tl in target_labels_split]
train_loader = [torch.utils.data.DataLoader(x, batch_size=batch_size, shuffle=True) for x in traindata_split]

test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('./data', train=False, transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,))])
        ), batch_size=batch_size, shuffle=True)

# Instantiate models and optimizers

global_model = Net() # .cuda()
client_models = [Net() for _ in range(num_selected)]
for model in client_models:
    model.load_state_dict(global_model.state_dict())

opt = [optim.SGD(model.parameters(), lr=0.1) for model in client_models]

# Runnining FL

for r in range(num_rounds):
    # select random clients
    client_idx = np.random.permutation(num_clients)[:num_selected]

    # client update
    loss = 0
    for i in range(num_selected):
        loss += client_update(client_models[i], opt[i], train_loader[client_idx[i]], epoch=epochs)
    
    # serer aggregate
    server_aggregate(global_model, client_models)
    test_loss, acc = test(global_model, test_loader)
    
    print('%d-th round' % r)
    print('average train loss %0.3g | test loss %0.3g | test acc: %0.3f' % (loss / num_selected, test_loss, acc))
# Out:
# 0-th round
# average train loss 0.164 | test loss 2.17 | test acc: 0.210
# 1-th round
# average train loss 0.0346 | test loss 2.28 | test acc: 0.388
# 2-th round
# average train loss 0.0108 | test loss 1.39 | test acc: 0.572
# 3-th round
# average train loss 0.0416 | test loss 1.87 | test acc: 0.490
# 4-th round
# average train loss 0.00216 | test loss 1.89 | test acc: 0.456
# 5-th round
# average train loss 0.00146 | test loss 1.69 | test acc: 0.476
# 6-th round
# average train loss 0.0205 | test loss 1.35 | test acc: 0.461
# 7-th round
# average train loss 0.00893 | test loss 0.846 | test acc: 0.715
# 8-th round
# average train loss 0.00126 | test loss 1 | test acc: 0.663
# 9-th round
# average train loss 0.00752 | test loss 1.55 | test acc: 0.435
# 10-th round
# average train loss 0.00118 | test loss 1.53 | test acc: 0.476
# 11-th round
# average train loss 0.000717 | test loss 1.6 | test acc: 0.494
# 12-th round
# average train loss 0.00162 | test loss 1.16 | test acc: 0.539
# 13-th round
# average train loss 0.00372 | test loss 1.24 | test acc: 0.570
# 14-th round
# average train loss 0.00133 | test loss 0.876 | test acc: 0.702
# 15-th round
# average train loss 0.00201 | test loss 1.5 | test acc: 0.565
# 16-th round
# average train loss 0.0033 | test loss 1.36 | test acc: 0.577
# 17-th round
# average train loss 0.000976 | test loss 1.13 | test acc: 0.652
# 18-th round
# average train loss 0.000479 | test loss 0.566 | test acc: 0.812
# 19-th round
# average train loss 0.00121 | test loss 0.897 | test acc: 0.718
# 20-th round
# average train loss 0.000601 | test loss 1.33 | test acc: 0.546
# 21-th round
# average train loss 0.00105 | test loss 0.799 | test acc: 0.741
# 22-th round
# average train loss 0.000658 | test loss 0.52 | test acc: 0.825
# 23-th round
# average train loss 0.00173 | test loss 0.496 | test acc: 0.826
# 24-th round
# average train loss 0.000491 | test loss 0.78 | test acc: 0.769
# 25-th round
# average train loss 0.00088 | test loss 0.843 | test acc: 0.702
# 26-th round
# average train loss 0.000727 | test loss 0.649 | test acc: 0.766
# 27-th round
# average train loss 0.000849 | test loss 0.489 | test acc: 0.826
# 28-th round
# average train loss 0.00095 | test loss 0.713 | test acc: 0.785
# 29-th round
# average train loss 0.000376 | test loss 0.529 | test acc: 0.831
# 30-th round
# average train loss 0.00069 | test loss 0.289 | test acc: 0.917
# 31-th round
# average train loss 0.000791 | test loss 0.28 | test acc: 0.906
# 32-th round
# average train loss 0.00117 | test loss 0.294 | test acc: 0.902
# 33-th round
# average train loss 0.000174 | test loss 0.302 | test acc: 0.894
# 34-th round
# average train loss 0.000179 | test loss 0.815 | test acc: 0.736
# 35-th round
# average train loss 0.000996 | test loss 0.856 | test acc: 0.735
# 36-th round
# average train loss 0.00119 | test loss 0.919 | test acc: 0.739
# 37-th round
# average train loss 0.0012 | test loss 0.445 | test acc: 0.835
# 38-th round
# average train loss 0.000332 | test loss 0.545 | test acc: 0.798
# 39-th round
# average train loss 0.000345 | test loss 0.232 | test acc: 0.928
# 40-th round
# average train loss 0.000452 | test loss 0.463 | test acc: 0.845
# 41-th round
# average train loss 8.28e-05 | test loss 0.422 | test acc: 0.850
# 42-th round
# average train loss 0.00078 | test loss 0.355 | test acc: 0.877
# 43-th round
# average train loss 0.000978 | test loss 0.367 | test acc: 0.860
# 44-th round
# average train loss 0.000661 | test loss 0.352 | test acc: 0.865
# 45-th round
# average train loss 0.000583 | test loss 0.431 | test acc: 0.843
# 46-th round
# average train loss 0.00023 | test loss 0.579 | test acc: 0.812
# 47-th round
# average train loss 0.000187 | test loss 0.405 | test acc: 0.854
# 48-th round
# average train loss 0.00012 | test loss 0.372 | test acc: 0.862
# 49-th round
# average train loss 0.000175 | test loss 0.299 | test acc: 0.890
